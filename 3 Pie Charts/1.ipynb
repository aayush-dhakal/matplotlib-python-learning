# %%
from matplotlib import pyplot as plt

# %%
plt.style.use("fivethirtyeight")

plt.title("My Awesome Pie Chart")
plt.tight_layout()

slices = [120, 80]
labels=['Sixty', 'Forty']

plt.pie(slices, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b3a52060>,
# ...
#  [Text(-0.33991877217145816, 1.046162142464278, 'Sixty'),
#   Text(0.3399188701202255, -1.0461621106387813, 'Forty')])

# %%
plt.pie(slices, labels=labels, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b3aafa70>,
# ...
#  [Text(-0.33991877217145816, 1.046162142464278, 'Sixty'),
#   Text(0.3399188701202255, -1.0461621106387813, 'Forty')])

# %%
plt.title("My Awesome Pie Chart")
plt.tight_layout()

slices = [120, 80, 30, 20]
labels=['Sixty', 'Forty', 'E1', 'E2']
colors=['blue', '#fc4f30', 'yellow', '#6d904f']

plt.pie(slices, labels=labels, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b74dade0>,
# ...
#  [Text(0.0690696084852792, 1.0978293989430645, 'Sixty'),
#   Text(-0.7011664649040888, -0.8475645040313471, 'Forty'),
#   Text(0.7011662863559625, -0.8475646517391985, 'E1'),
#   Text(1.0654414403595847, -0.27355901952685396, 'E2')])

# %%
# Language Popularity
# means 59219 people said they knew javascript
slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']
plt.pie(slices, labels=labels, wedgeprops={'edgecolor':'black'})
# do not use pie chart to compare large data set rather use bar chart.
# use pie chart to compare around 5 different data sets
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b78333e0>,
# ...
#  [Text(0.9843226122588631, 0.491028507314889, 'JavaScript'),
#   Text(0.23139477667444028, 1.0753866548027207, 'HTML/CSS'),
#   Text(-0.6146994255065557, 0.9122196096784537, 'SQL'),
#   Text(-1.0436117179515185, 0.34767022040186357, 'Python'),
#   Text(-1.0674624570178632, -0.26556336881691117, 'Java'),
#   Text(-0.7862856172007463, -0.7692560875178315, 'Bash/Shell/PowerShell'),
#   Text(-0.36127463681325483, -1.0389805757546438, 'C#'),
#   Text(0.06271087631612919, -1.098210975173561, 'PHP'),
#   Text(0.4256878521252104, -1.0142927844330873, 'C++'),
#   Text(0.7107154038569522, -0.8395734719013277, 'TypeScript'),
#   Text(0.9184117306636805, -0.6054088643052259, 'C'),
#   Text(1.021473009537878, -0.408157923830508, 'Other(s):'),
#   Text(1.062753092216688, -0.2838236512059353, 'Ruby'),
#   Text(1.088068122601307, -0.16157896081751277, 'Go'),
#   Text(1.0988576487863024, -0.050118536529305716, 'Assembly')])

# %%
plt.title("My Awesome Pie Chart")

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
plt.pie(slices, labels=labels, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b78bd850>,
# ...
#  [Text(0.7718391274789096, 0.7837501906172628, 'JavaScript'),
#   Text(-0.7563043225037828, 0.7987513829484705, 'HTML/CSS'),
#   Text(-0.9279786422142811, -0.5906400253912187, 'SQL'),
#   Text(0.1325149391889142, -1.0919889151872186, 'Python'),
#   Text(0.9751875080557701, -0.5089295866148649, 'Java')])

# %%
plt.title("My Awesome Pie Chart")

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0] # emphasis on python at 4th index. 0.1 means 10% out of the radius

plt.pie(slices, labels=labels, explode=explode, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b7996630>,
# ...
#  [Text(0.7718391274789096, 0.7837501906172628, 'JavaScript'),
#   Text(-0.7563043225037828, 0.7987513829484705, 'HTML/CSS'),
#   Text(-0.9279786422142811, -0.5906400253912187, 'SQL'),
#   Text(0.14456175184245185, -1.191260634749693, 'Python'),
#   Text(0.9751875080557701, -0.5089295866148649, 'Java')])

# %%
plt.title("My Awesome Pie Chart")

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.3, 0]

plt.pie(slices, labels=labels, explode=explode, shadow=True, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b7a08440>,
# ...
#  [Text(0.7718391274789096, 0.7837501906172628, 'JavaScript'),
#   Text(-0.7563043225037828, 0.7987513829484705, 'HTML/CSS'),
#   Text(-0.9279786422142811, -0.5906400253912187, 'SQL'),
#   Text(0.16865537714952714, -1.3898040738746418, 'Python'),
#   Text(0.9751875080557701, -0.5089295866148649, 'Java')])

# %%
plt.title("My Awesome Pie Chart")

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.3, 0]

plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b7a60560>,
# ...
#  [Text(-0.7837501906172629, 0.7718391274789094, 'JavaScript'),
#   Text(-0.7987513829484706, -0.7563043225037827, 'HTML/CSS'),
#   Text(0.5906400253912186, -0.9279786422142812, 'SQL'),
#   Text(1.3898040738746418, 0.16865537714952708, 'Python'),
#   Text(0.508929586614865, 0.9751875080557701, 'Java')])

# %%
plt.title("My Awesome Pie Chart")

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.3, 0]

# add percentage value with autopct
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=45, autopct='%1.1f%%', wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x2a4b7b75370>,
# ...
#  [Text(-0.008422393516270648, 1.0999677555671608, 'JavaScript'),
#   Text(-1.0995904344481189, 0.03001460428187405, 'HTML/CSS'),
#   Text(-0.23853442351167778, -1.0738255579003286, 'SQL'),
#   Text(1.101997246023454, -0.8634825242914435, 'Python'),
#   Text(1.0494292617164833, 0.3296941380328086, 'Java')],
#  [Text(-0.004594032827056717, 0.5999824121275422, '25.2%'),
#   Text(-0.5997766006080647, 0.01637160233556766, '23.6%'),
#   Text(-0.13010968555182423, -0.5857230315819973, '20.3%'),
#   Text(0.7084268010150775, -0.5550959084730707, '15.5%'),
#   Text(0.5724159609362636, 0.1798331661997138, '15.3%')])
